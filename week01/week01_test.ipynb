# %% [markdown]
# <a href="https://colab.research.google.com/github/sejinov/ai-programming-2026/blob/main/week01/week01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TODO: ___ 를 본인 이름과 학과로 바꾸세요.
print('이름:', '오세진')
print('학과:', '정보컴퓨터공학부 컴퓨터공학전공')

print("기대: 위 두 줄의 밑줄 자리가 본인 이름과 학과로 바뀌어 출력됩니다")
# Out:
# 이름: 오세진
# 학과: 정보컴퓨터공학부 컴퓨터공학전공
# 기대: 위 두 줄의 밑줄 자리가 본인 이름과 학과로 바뀌어 출력됩니다
